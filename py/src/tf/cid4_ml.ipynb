# %% [markdown]
# ## Regression

# %%
import tensorflow as tf

tf.__version__
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776707977.846776   26836 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776707982.699476   26836 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776707995.334738   26836 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# '2.21.0'

# %%
from src.tf.datasets import build_activity_value_regression_dataset
from src.tf.tensorflow_workflows import run_tensorflow_regression

regression_dataset = build_activity_value_regression_dataset()
run_tensorflow_regression(regression_dataset)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776708789.101463   29273 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776708789.174142   29273 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776708790.832042   29273 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# E0000 00:00:1776708792.796270   29273 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# {'library': 'tensorflow',
#  'dataset': {'name': 'bioactivity-activity-value-regression',
#   'task_type': 'regression',
#   'row_count': 2,
#   'feature_count': 34,
#   'feature_columns': ['C_count',
#    'H_count',
#    'N_count',
#    'O_count',
#    'bond_count_total',
#    'mol_weight',
#    'has_chiral_center',
#    'Aid_Type_Encoded',
#    'Activity_Type_Encoded',
#    'Bioassay_Data_Source_Encoded',
#    'Has_Dose_Response_Curve',
#    'RNAi_BioAssay',
#    'Taxonomy_ID_Numeric',
#    'Target_Taxonomy_ID_Numeric',
#    'Has_Protein_Accession',
#    'Has_Gene_ID',
#    'Has_PMID',
#    'Has_Activity_Value',
#    'BioAssay_Name_Has_qHTS',
#    'BioAssay_Name_Has_IC50',
#    'BioAssay_Name_Has_Counter_Screen',
#    'BioAssay_Name_Has_Estrogen',
#    'BioAssay_Name_Has_Androgen',
#    'BioAssay_Name_Has_Cytochrome',
#    'BioAssay_Name_Has_Plasmodium',
#    'BioAssay_Name_Has_Yeast',
#    'Target_Name_Has_Estrogen',
#    'Target_Name_Has_Androgen',
#    'Target_Name_Has_Cytochrome',
#    'Target_Name_Has_Plasmodium',
#    'Target_Name_Has_Yeast',
#    'Bioassay_Source_Has_Tox21',
#    'Bioassay_Source_Has_ChEMBL',
#    'Bioassay_Source_Has_DTP_NCI'],
#   'target_column': 'Activity_Value',
#   'class_names': None,
#   'description': 'Positive numeric Activity_Value regression dataset using molecular descriptors and assay metadata.'},
#  'evaluation_note': 'Dataset is too small for a stable holdout split, so evaluation is reported on the training rows.',
#  'epochs': 300,
#  'metrics': {'mae': 399.77124819869994,
#   'rmse': 555.3563297647578,
#   'r2': -1.0375196408712526}}

# %% [markdown]
# ## Bioactivity binary classification

# %%
from src.tf.datasets import build_bioactivity_binary_classification_dataset
from src.tf.tensorflow_workflows import run_tensorflow_classification

bioactivity_dataset = build_bioactivity_binary_classification_dataset()
tensorflow_classification_result = run_tensorflow_classification(bioactivity_dataset)
tensorflow_classification_result
# Out:
# {'status': 'insufficient_data',
#  'library': 'tensorflow',
#  'dataset': {'name': 'bioactivity-active-vs-inactive',
#   'task_type': 'classification',
#   'row_count': 3,
#   'feature_count': 34,
#   'feature_columns': ['C_count',
#    'H_count',
#    'N_count',
#    'O_count',
#    'bond_count_total',
#    'mol_weight',
#    'has_chiral_center',
#    'Aid_Type_Encoded',
#    'Activity_Type_Encoded',
#    'Bioassay_Data_Source_Encoded',
#    'Has_Dose_Response_Curve',
#    'RNAi_BioAssay',
#    'Taxonomy_ID_Numeric',
#    'Target_Taxonomy_ID_Numeric',
#    'Has_Protein_Accession',
#    'Has_Gene_ID',
#    'Has_PMID',
#    'Has_Activity_Value',
#    'BioAssay_Name_Has_qHTS',
#    'BioAssay_Name_Has_IC50',
#    'BioAssay_Name_Has_Counter_Screen',
#    'BioAssay_Name_Has_Estrogen',
#    'BioAssay_Name_Has_Androgen',
#    'BioAssay_Name_Has_Cytochrome',
#    'BioAssay_Name_Has_Plasmodium',
#    'BioAssay_Name_Has_Yeast',
#    'Target_Name_Has_Estrogen',
#    'Target_Name_Has_Androgen',
#    'Target_Name_Has_Cytochrome',
#    'Target_Name_Has_Plasmodium',
#    'Target_Name_Has_Yeast',
#    'Bioassay_Source_Has_Tox21',
#    'Bioassay_Source_Has_ChEMBL',
#    'Bioassay_Source_Has_DTP_NCI'],
#   'target_column': 'activityBinary',
#   'class_names': ['inactive', 'active'],
#   'description': 'Filtered Active vs Inactive assay rows using constant molecular descriptors and assay metadata.'},
#  'reason': 'TensorFlow classification requires at least two target classes.'}

# %% [markdown]
# ## Heavy atom classification

# %%
from src.tf.tensorflow_workflows import run_tensorflow_classification

# %%
from src.tf.datasets import build_atom_heavy_atom_dataset

atom_heavy_dataset = build_atom_heavy_atom_dataset()
run_tensorflow_classification(atom_heavy_dataset)
# Out:
# {'status': 'ok',
#  'library': 'tensorflow',
#  'dataset': {'name': 'atom-heavy-vs-hydrogen',
#   'task_type': 'classification',
#   'row_count': 14,
#   'feature_count': 7,
#   'feature_columns': ['bondCount',
#    'totalHydrogenCount',
#    'valency',
#    'mass',
#    'hybridizationEncoded',
#    'isAromaticInt',
#    'charge'],
#   'target_column': 'isHeavyAtom',
#   'class_names': ['hydrogen', 'heavy_atom'],
#   'description': 'Atom-level binary classification from conformer-derived RDKit features.'},
#  'evaluation_note': 'Evaluation uses a deterministic holdout split.',
#  'epochs': 200,
#  'metrics': {'accuracy': 1.0,
#   'macro_f1': 1.0,
#   'confusion_matrix': [[3, 0], [0, 2]],
#   'class_names': ['hydrogen', 'heavy_atom']}}

# %%
from src.tf.datasets import build_atom_element_dataset

atom_element_dataset = build_atom_element_dataset()
run_tensorflow_classification(atom_element_dataset)
# Out:
# {'status': 'ok',
#  'library': 'tensorflow',
#  'dataset': {'name': 'atom-element-multiclass',
#   'task_type': 'classification',
#   'row_count': 14,
#   'feature_count': 7,
#   'feature_columns': ['bondCount',
#    'totalHydrogenCount',
#    'valency',
#    'mass',
#    'hybridizationEncoded',
#    'isAromaticInt',
#    'charge'],
#   'target_column': 'elementTarget',
#   'class_names': ['C', 'H', 'N', 'O'],
#   'description': 'Atom-level multiclass classification over O/N/C/H using non-symbol features.'},
#  'evaluation_note': 'Dataset is too small for a stable holdout split, so evaluation is reported on the training rows.',
#  'epochs': 200,
#  'metrics': {'accuracy': 0.9285714285714286,
#   'macro_f1': 0.7142857142857143,
#   'confusion_matrix': [[3, 0, 0, 0], [0, 9, 0, 0], [1, 0, 0, 0], [0, 0, 0, 1]],
#   'class_names': ['C', 'H', 'N', 'O']}}
