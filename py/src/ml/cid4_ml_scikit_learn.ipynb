# %% [markdown]
# ## Setup

# %%
from utils import fs_utils as fs

output_directory = fs.resolve_output_directory()
display(output_directory)
# Out:
# PosixPath('/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/data/out')

# %% [markdown]
# ## Linear regression

# %%
from ml.datasets import build_activity_value_regression_dataset
from ml.sklearn_workflows import run_linear_regression

regression_dataset = build_activity_value_regression_dataset()
display(regression_dataset)
regression_dataset.frame.to_csv(output_directory / "cid4_ml.bioactivity_regression_features.csv", index=False)
linear_regression = run_linear_regression(regression_dataset)
linear_regression
# Out:
# PreparedDataset(name='bioactivity-activity-value-regression', task_type='regression', frame=   Bioactivity_ID      Aid_Type     Activity Protein_Accession Activity_Type  \
# 0       334754348  Confirmatory  Unspecified          AEP43755       Potency
# 1       100909607  Confirmatory        Probe               NaN          IC50
#
#   Activity_Qualifier Bioassay_Data_Source  \
# 0                NaN                Tox21
# 1                  =               ChEMBL
#
#                                        BioAssay_Name       Compound_Name  \
# 0  qHTS assay to identify small molecule antagoni...  1-Amino-2-propanol
# 1  Inhibitory activity against Plasmodium falciparum  1-Amino-2-propanol
#
#                                          Target_Name  ...  \
# 0                 ESR1 - estrogen receptor 1 (human)  ...
# 1  Plasmodium falciparum (malaria parasite P. fal...  ...
#
#   BioAssay_Name_Has_Plasmodium BioAssay_Name_Has_Yeast  \
# ...

# %% [markdown]
# ## Activity value regression

# %%
from ml.datasets import build_activity_value_regression_dataset

regression_dataset = build_activity_value_regression_dataset()

# %% [markdown]
# ### XGBoost regression

# %%
from ml.xgboost_workflows import run_xgboost_regression

run_xgboost_regression(regression_dataset)
# Out:
# {'library': 'xgboost',
#  'dataset': {'name': 'bioactivity-activity-value-regression',
#   'task_type': 'regression',
#   'row_count': 2,
#   'feature_count': 34,
#   'feature_columns': ['C_count',
#    'H_count',
#    'N_count',
#    'O_count',
#    'bond_count_total',
#    'mol_weight',
#    'has_chiral_center',
#    'Aid_Type_Encoded',
#    'Activity_Type_Encoded',
#    'Bioassay_Data_Source_Encoded',
#    'Has_Dose_Response_Curve',
#    'RNAi_BioAssay',
#    'Taxonomy_ID_Numeric',
#    'Target_Taxonomy_ID_Numeric',
#    'Has_Protein_Accession',
#    'Has_Gene_ID',
#    'Has_PMID',
#    'Has_Activity_Value',
#    'BioAssay_Name_Has_qHTS',
#    'BioAssay_Name_Has_IC50',
#    'BioAssay_Name_Has_Counter_Screen',
#    'BioAssay_Name_Has_Estrogen',
#    'BioAssay_Name_Has_Androgen',
#    'BioAssay_Name_Has_Cytochrome',
#    'BioAssay_Name_Has_Plasmodium',
#    'BioAssay_Name_Has_Yeast',
#    'Target_Name_Has_Estrogen',
#    'Target_Name_Has_Androgen',
# ...

# %% [markdown]
# ### PyTorch regression

# %%
import torch

torch.__version__
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/py/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/py/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
from ml.torch_workflows import run_torch_regression

run_torch_regression(regression_dataset)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/py/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/py/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
# ...

# %% [markdown]
# ### TensorFlow regression

# %%
import tensorflow as tf

tf.__version__
# Out:
# 2026-04-16 22:22:08.490947: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# '2.18.0'

# %%
from ml.tensorflow_workflows import run_tensorflow_regression

run_tensorflow_regression(regression_dataset)
# Out:
# 2026-04-16 19:59:54.671925: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# {'library': 'tensorflow',
#  'dataset': {'name': 'bioactivity-activity-value-regression',
#   'task_type': 'regression',
#   'row_count': 2,
#   'feature_count': 34,
#   'feature_columns': ['C_count',
#    'H_count',
#    'N_count',
#    'O_count',
#    'bond_count_total',
#    'mol_weight',
#    'has_chiral_center',
#    'Aid_Type_Encoded',
#    'Activity_Type_Encoded',
#    'Bioassay_Data_Source_Encoded',
#    'Has_Dose_Response_Curve',
#    'RNAi_BioAssay',
#    'Taxonomy_ID_Numeric',
#    'Target_Taxonomy_ID_Numeric',
#    'Has_Protein_Accession',
#    'Has_Gene_ID',
#    'Has_PMID',
#    'Has_Activity_Value',
# ...

# %% [markdown]
# ## Logistic regression

# %%
from ml.sklearn_workflows import run_logistic_regression

# %%
from ml.datasets import build_atom_heavy_atom_dataset

atom_heavy_dataset = build_atom_heavy_atom_dataset()
display(atom_heavy_dataset)
atom_heavy_dataset.frame.to_csv(output_directory / "cid4_ml.atom_heavy_binary_features.csv", index=False)
heavy_atom_logistic_regression = run_logistic_regression(atom_heavy_dataset)
heavy_atom_logistic_regression

# %%
from ml.datasets import build_atom_element_dataset

atom_element_dataset = build_atom_element_dataset()
display(atom_element_dataset)
atom_element_dataset.frame.to_csv(output_directory / "cid4_ml.atom_element_binary_features.csv", index=False)
atom_element_logistic_regression = run_logistic_regression(atom_element_dataset)
atom_element_logistic_regression

# %%
from ml.datasets import build_bioactivity_binary_classification_dataset

bioactivity_dataset = build_bioactivity_binary_classification_dataset()
display(bioactivity_dataset)
bioactivity_dataset.frame.to_csv(output_directory / "cid4_ml.bioactivity_binary_features.csv", index=False)
logistic_regression = run_logistic_regression(bioactivity_dataset)
logistic_regression
# Out:
# PreparedDataset(name='bioactivity-active-vs-inactive', task_type='classification', frame=   Bioactivity_ID Aid_Type Activity Protein_Accession Activity_Type  \
# 0        32761399    Other   Active               NaN       Unknown
# 1       351848396    Other   Active               NaN       Unknown
# 2       351848428    Other   Active               NaN       Unknown
#
#   Activity_Qualifier                               Bioassay_Data_Source  \
# 0                NaN                                         EPA DSSTox
# 1                NaN  Chemical Carcinogenesis Research Information S...
# 2                NaN  Chemical Carcinogenesis Research Information S...
#
#                                        BioAssay_Name       Compound_Name  \
# 0  DSSTox (EPAFHM) EPA Fathead Minnow Acute Toxicity  1-Amino-2-propanol
# 1                         CCRIS mutagenicity studies  1-Amino-2-propanol
# 2                         CCRIS mutagenicity studies  1-Amino-2-propanol
#
# ...

# %% [markdown]
# ## Bioactivity binary classification

# %%
from ml.datasets import build_bioactivity_binary_classification_dataset

bioactivity_dataset = build_bioactivity_binary_classification_dataset()

# %% [markdown]
# ### XGBoost classification

# %%
from ml.xgboost_workflows import run_xgboost_classification

xgboost_result = run_xgboost_classification(bioactivity_dataset)
xgboost_result
# Out:
# {'status': 'insufficient_data',
#  'library': 'xgboost',
#  'dataset': {'name': 'bioactivity-active-vs-inactive',
#   'task_type': 'classification',
#   'row_count': 3,
#   'feature_count': 34,
#   'feature_columns': ['C_count',
#    'H_count',
#    'N_count',
#    'O_count',
#    'bond_count_total',
#    'mol_weight',
#    'has_chiral_center',
#    'Aid_Type_Encoded',
#    'Activity_Type_Encoded',
#    'Bioassay_Data_Source_Encoded',
#    'Has_Dose_Response_Curve',
#    'RNAi_BioAssay',
#    'Taxonomy_ID_Numeric',
#    'Target_Taxonomy_ID_Numeric',
#    'Has_Protein_Accession',
#    'Has_Gene_ID',
#    'Has_PMID',
#    'Has_Activity_Value',
#    'BioAssay_Name_Has_qHTS',
#    'BioAssay_Name_Has_IC50',
#    'BioAssay_Name_Has_Counter_Screen',
#    'BioAssay_Name_Has_Estrogen',
#    'BioAssay_Name_Has_Androgen',
#    'BioAssay_Name_Has_Cytochrome',
#    'BioAssay_Name_Has_Plasmodium',
#    'BioAssay_Name_Has_Yeast',
#    'Target_Name_Has_Estrogen',
#    'Target_Name_Has_Androgen',
# ...

# %% [markdown]
# ### Tensorflow classification

# %%
from ml.tensorflow_workflows import run_tensorflow_classification

tensorflow_classification_result = run_tensorflow_classification(bioactivity_dataset)
tensorflow_classification_result
# Out:
# 2026-04-17 10:34:08.605324: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# {'status': 'insufficient_data',
#  'library': 'tensorflow',
#  'dataset': {'name': 'bioactivity-active-vs-inactive',
#   'task_type': 'classification',
#   'row_count': 3,
#   'feature_count': 34,
#   'feature_columns': ['C_count',
#    'H_count',
#    'N_count',
#    'O_count',
#    'bond_count_total',
#    'mol_weight',
#    'has_chiral_center',
#    'Aid_Type_Encoded',
#    'Activity_Type_Encoded',
#    'Bioassay_Data_Source_Encoded',
#    'Has_Dose_Response_Curve',
#    'RNAi_BioAssay',
#    'Taxonomy_ID_Numeric',
#    'Target_Taxonomy_ID_Numeric',
#    'Has_Protein_Accession',
#    'Has_Gene_ID',
#    'Has_PMID',
# ...

# %% [markdown]
# ## PyTorch bioactivity binary classification

# %%
from ml.torch_workflows import run_torch_classification
from ml.datasets import build_bioactivity_binary_classification_dataset

bioactivity_dataset = build_bioactivity_binary_classification_dataset()
run_torch_classification(bioactivity_dataset)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/py/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/py/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
# ...

# %% [markdown]
# ## PyTorch atom element multiclass classification

# %%
from ml.datasets import build_atom_element_dataset
from ml.torch_workflows import run_torch_classification

atom_element_dataset = build_atom_element_dataset()
run_torch_classification(atom_element_dataset)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from ml.datasets import build_atom_element_dataset
# ----> 2 from ml.torch_workflows import run_torch_classification
#       4 atom_element_dataset = build_atom_element_dataset()
#       5 run_torch_classification(atom_element_dataset)
#
# ImportError: cannot import name 'run_torch_classification' from 'ml.torch_workflows' (/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/py/src/ml/torch_workflows.py)

# %% [markdown]
# # PyTorch heavy atom vs hydrogen

# %%
from ml.datasets import build_atom_heavy_atom_dataset
from ml.torch_workflows import run_torch_classification

atom_heavy_dataset = build_atom_heavy_atom_dataset()
run_torch_classification(atom_heavy_dataset)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from ml.datasets import build_atom_heavy_atom_dataset
# ----> 2 from ml.torch_workflows import run_torch_classification
#       4 atom_heavy_dataset = build_atom_heavy_atom_dataset()
#       5 run_torch_classification(atom_heavy_dataset)
#
# ImportError: cannot import name 'run_torch_classification' from 'ml.torch_workflows' (/Users/Artsem_Nikitsenka/projects/pubchem-cid4-analysis/py/src/ml/torch_workflows.py)

# %% [markdown]
# ## Heavy atom classification

# %%
from ml.tensorflow_workflows import run_tensorflow_classification
# Out:
# 2026-04-17 11:29:29.975807: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from ml.datasets import build_atom_heavy_atom_dataset

atom_heavy_dataset = build_atom_heavy_atom_dataset()
run_tensorflow_classification(atom_heavy_dataset)
# Out:
# 2026-04-17 10:50:16.228613: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from ml.datasets import build_atom_element_dataset

atom_element_dataset = build_atom_element_dataset()
run_tensorflow_classification(atom_element_dataset)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## SVM

# %%
from ml.datasets import build_bioactivity_binary_classification_dataset
from ml.sklearn_workflows import run_svm

bioactivity_dataset = build_bioactivity_binary_classification_dataset()
display(bioactivity_dataset)
bioactivity_dataset.frame.to_csv(output_directory / "cid4_ml.bioactivity_svm_features.csv", index=False)
svm_result = run_svm(bioactivity_dataset)
svm_result
# Out:
# PreparedDataset(name='bioactivity-active-vs-inactive', task_type='classification', frame=   Bioactivity_ID Aid_Type Activity Protein_Accession Activity_Type  \
# 0        32761399    Other   Active               NaN       Unknown
# 1       351848396    Other   Active               NaN       Unknown
# 2       351848428    Other   Active               NaN       Unknown
#
#   Activity_Qualifier                               Bioassay_Data_Source  \
# 0                NaN                                         EPA DSSTox
# 1                NaN  Chemical Carcinogenesis Research Information S...
# 2                NaN  Chemical Carcinogenesis Research Information S...
#
#                                        BioAssay_Name       Compound_Name  \
# 0  DSSTox (EPAFHM) EPA Fathead Minnow Acute Toxicity  1-Amino-2-propanol
# 1                         CCRIS mutagenicity studies  1-Amino-2-propanol
# 2                         CCRIS mutagenicity studies  1-Amino-2-propanol
#
# ...

# %% [markdown]
# ## KNN

# %%
from ml.datasets import build_atom_heavy_atom_dataset
from ml.sklearn_workflows import run_knn

atom_heavy_dataset = build_atom_heavy_atom_dataset()
display(atom_heavy_dataset)
atom_heavy_dataset.frame.to_csv(output_directory / "cid4_ml.atom_heavy_knn_classification.csv", index=False)
knn_classification = run_knn(atom_heavy_dataset)
knn_classification
# Out:
# PreparedDataset(name='atom-heavy-vs-hydrogen', task_type='classification', frame=   atomLabel  bondCount  totalHydrogenCount  valency    mass  \
# 0         O1          2                   0        2  15.999
# 1         N2          3                   0        3  14.007
# 2         C3          4                   0        4  12.011
# 3         C4          4                   0        4  12.011
# 4         C5          4                   0        4  12.011
# 5         H6          1                   0        1   1.008
# 6         H7          1                   0        1   1.008
# 7         H8          1                   0        1   1.008
# 8         H9          1                   0        1   1.008
# 9        H10          1                   0        1   1.008
# 10       H11          1                   0        1   1.008
# 11       H12          1                   0        1   1.008
# 12       H13          1                   0        1   1.008
# ...

# %%
from ml.sklearn_workflows import run_atom_neighbor_report

knn_neighbors = run_atom_neighbor_report(atom_heavy_dataset)
knn_neighbors
# Out:
# {'dataset': {'name': 'atom-heavy-vs-hydrogen',
#   'task_type': 'classification',
#   'row_count': 14,
#   'feature_count': 7,
#   'feature_columns': ['bondCount',
#    'totalHydrogenCount',
#    'valency',
#    'mass',
#    'hybridizationEncoded',
#    'isAromaticInt',
#    'charge'],
#   'target_column': 'isHeavyAtom',
#   'class_names': ['hydrogen', 'heavy_atom'],
#   'description': 'Atom-level binary classification from conformer-derived RDKit features.'},
#  'query_atom': 'O1',
#  'neighbors': [{'atom': 'O1', 'distance': 0.0},
#   {'atom': 'N2', 'distance': 2.4429621364237315},
#   {'atom': 'C4', 'distance': 4.88918643538984},
#   {'atom': 'C3', 'distance': 4.88918643538984}]}

# %% [markdown]
# ## Decision tree

# %%
from ml.datasets import build_bioactivity_binary_classification_dataset
from ml.sklearn_workflows import run_decision_tree

bioactivity_dataset = build_bioactivity_binary_classification_dataset()
display(bioactivity_dataset)
run_decision_tree(bioactivity_dataset)
# Out:
# PreparedDataset(name='bioactivity-active-vs-inactive', task_type='classification', frame=   Bioactivity_ID Aid_Type Activity Protein_Accession Activity_Type  \
# 0        32761399    Other   Active               NaN       Unknown
# 1       351848396    Other   Active               NaN       Unknown
# 2       351848428    Other   Active               NaN       Unknown
#
#   Activity_Qualifier                               Bioassay_Data_Source  \
# 0                NaN                                         EPA DSSTox
# 1                NaN  Chemical Carcinogenesis Research Information S...
# 2                NaN  Chemical Carcinogenesis Research Information S...
#
#                                        BioAssay_Name       Compound_Name  \
# 0  DSSTox (EPAFHM) EPA Fathead Minnow Acute Toxicity  1-Amino-2-propanol
# 1                         CCRIS mutagenicity studies  1-Amino-2-propanol
# 2                         CCRIS mutagenicity studies  1-Amino-2-propanol
#
# ...

# %% [markdown]
# ## Random forest

# %%
from ml.datasets import build_bioactivity_binary_classification_dataset
from ml.sklearn_workflows import run_random_forest

bioactivity_dataset = build_bioactivity_binary_classification_dataset()
display(bioactivity_dataset)
run_random_forest(bioactivity_dataset)
# Out:
# PreparedDataset(name='bioactivity-active-vs-inactive', task_type='classification', frame=   Bioactivity_ID Aid_Type Activity Protein_Accession Activity_Type  \
# 0        32761399    Other   Active               NaN       Unknown
# 1       351848396    Other   Active               NaN       Unknown
# 2       351848428    Other   Active               NaN       Unknown
#
#   Activity_Qualifier                               Bioassay_Data_Source  \
# 0                NaN                                         EPA DSSTox
# 1                NaN  Chemical Carcinogenesis Research Information S...
# 2                NaN  Chemical Carcinogenesis Research Information S...
#
#                                        BioAssay_Name       Compound_Name  \
# 0  DSSTox (EPAFHM) EPA Fathead Minnow Acute Toxicity  1-Amino-2-propanol
# 1                         CCRIS mutagenicity studies  1-Amino-2-propanol
# 2                         CCRIS mutagenicity studies  1-Amino-2-propanol
#
# ...

# %% [markdown]
# ## K-Means

# %%
from ml.datasets import build_atom_feature_frame
from ml.sklearn_workflows import run_kmeans

atom_feature_df, _ = build_atom_feature_frame()
display(atom_feature_df)
atom_feature_df.to_csv(output_directory / "cid4_ml.atom_features.csv", index=False)
run_kmeans(atom_feature_df)
# Out:
#     moleculeIndex  index  bondCount  charge  implicitHydrogenCount  \
# 0               0      0          2       0                      0
# 1               0      1          3       0                      0
# 2               0      2          4       0                      0
# 3               0      3          4       0                      0
# 4               0      4          4       0                      0
# 5               0      5          1       0                      0
# 6               0      6          1       0                      0
# 7               0      7          1       0                      0
# 8               0      8          1       0                      0
# 9               0      9          1       0                      0
# 10              0     10          1       0                      0
# 11              0     11          1       0                      0
# 12              0     12          1       0                      0
# ...

# %% [markdown]
# ## Hierarchical Clustering

# %%
from ml.datasets import build_taxonomy_clustering_frame
from ml.sklearn_workflows import run_hierarchical_clustering

taxonomy_frame = build_taxonomy_clustering_frame()
display(taxonomy_frame)
taxonomy_frame.to_csv(output_directory / "cid4_ml.taxonomy_features.csv", index=False)

run_hierarchical_clustering()
# Out:
#              Source_Organism                                    Taxonomy  \
# 0              Gallus gallus                     Gallus gallus (chicken)
# 1   Dromaius novaehollandiae              Dromaius novaehollandiae (emu)
# 2           Struthio camelus          Struthio camelus (African ostrich)
# 3                 Ovis aries                          Ovis aries (sheep)
# 4                 Bos taurus                Bos taurus (domestic cattle)
# 5   Bos taurus X Bison bison          Bos taurus x Bison bison (beefalo)
# 6              Lepus timidus               Lepus timidus (Mountain hare)
# 7                 Sus scrofa                            Sus scrofa (pig)
# 8         Anas platyrhynchos                Anas platyrhynchos (mallard)
# 9           Numida meleagris      Numida meleagris (helmeted guineafowl)
# 10       Phasianus colchicus  Phasianus colchicus (ring-necked pheasant)
# 11                   Columba                                     Columba
# ...

# %% [markdown]
# ## PCA

# %%
from ml.datasets import build_heavy_atom_pca_dataset
from ml.sklearn_workflows import run_pca

heavy_atom_pca_dataset = build_heavy_atom_pca_dataset()
display(heavy_atom_pca_dataset)
run_pca(heavy_atom_pca_dataset)
# Out:
# PreparedDataset(name='heavy-atom-pca', task_type='embedding', frame=  atomLabel  atomicNumber  bondCount  totalHydrogenCount  valency    mass  \
# 0        O1             8          2                   0        2  15.999
# 1        N2             7          3                   0        3  14.007
# 2        C3             6          4                   0        4  12.011
# 3        C4             6          4                   0        4  12.011
# 4        C5             6          4                   0        4  12.011
#
#    hybridizationEncoded  isAromaticInt
# 0                     1              0
# 1                     1              0
# 2                     1              0
# 3                     1              0
# ...

# %% [markdown]
# ## Naive Bayes

# %%
from ml.datasets import build_atom_heavy_atom_dataset
from ml.sklearn_workflows import run_naive_bayes

atom_heavy_dataset = build_atom_heavy_atom_dataset()
display(atom_heavy_dataset)
run_naive_bayes(atom_heavy_dataset)
# Out:
# PreparedDataset(name='atom-heavy-vs-hydrogen', task_type='classification', frame=   atomLabel  bondCount  totalHydrogenCount  valency    mass  \
# 0         O1          2                   0        2  15.999
# 1         N2          3                   0        3  14.007
# 2         C3          4                   0        4  12.011
# 3         C4          4                   0        4  12.011
# 4         C5          4                   0        4  12.011
# 5         H6          1                   0        1   1.008
# 6         H7          1                   0        1   1.008
# 7         H8          1                   0        1   1.008
# 8         H9          1                   0        1   1.008
# 9        H10          1                   0        1   1.008
# 10       H11          1                   0        1   1.008
# 11       H12          1                   0        1   1.008
# 12       H13          1                   0        1   1.008
# ...
