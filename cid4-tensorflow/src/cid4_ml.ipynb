# %% [markdown]
# ## Regression

# %%
import tensorflow as tf

tf.__version__
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776628392.364296      13 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776628392.369361      13 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776628392.441995      13 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776628399.484867      13 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776628399.486553      13 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# '2.21.0'

# %%
from datasets import build_activity_value_regression_dataset
from tensorflow_workflows import run_tensorflow_regression

regression_dataset = build_activity_value_regression_dataset()
run_tensorflow_regression(regression_dataset)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from datasets import build_activity_value_regression_dataset
#       2 from tensorflow_workflows import run_tensorflow_regression
#       3
#       4 regression_dataset = build_activity_value_regression_dataset()
#
# ModuleNotFoundError: No module named 'datasets'

# %% [markdown]
# ## Bioactivity binary classification

# %%
from datasets import build_bioactivity_binary_classification_dataset
from tensorflow_workflows import run_tensorflow_classification

bioactivity_dataset = build_bioactivity_binary_classification_dataset()
tensorflow_classification_result = run_tensorflow_classification(bioactivity_dataset)
tensorflow_classification_result

# %% [markdown]
# ## Heavy atom classification

# %%
from tensorflow_workflows import run_tensorflow_classification

# %%
from datasets import build_atom_heavy_atom_dataset

atom_heavy_dataset = build_atom_heavy_atom_dataset()
run_tensorflow_classification(atom_heavy_dataset)

# %%
from datasets import build_atom_element_dataset

atom_element_dataset = build_atom_element_dataset()
run_tensorflow_classification(atom_element_dataset)
